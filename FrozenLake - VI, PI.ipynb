# %%
import gym
import numpy as np
import random
from timeit import default_timer as timer
from datetime import timedelta
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns

# %%
from gym.envs.toy_text.frozen_lake import generate_random_map, FrozenLakeEnv
np.random.seed(2)
sixteen = generate_random_map(16)
np.random.seed(44)
tvelve = generate_random_map(12)
MAPS = {
    "4x4": [
        "SFFF",
        "FHFH",
        "FFFH",
        "HFFG"
    ],
    "8x8": [
        "SFFFFFFF",
        "FFFFFFFF",
        "FFFHFFFF",
        "FFFFFHFF",
        "FFFHFFFF",
        "FHHFFFHF",
        "FHFFHFHF",
        "FFFHFFFG"
    ],
    "12x12": tvelve,
    "16x16": sixteen
}

# %%
def test_policy(env, policy, n_epoch=1000):
    rewards = []
    episode_counts = []
    for i in range(n_epoch):
        current_state = env.reset()
        ep = 0
        done = False
        episode_reward = 0
        while not done and ep < 1000:
            ep += 1
            act = int(policy[current_state])
            new_state, reward, done, _ = env.step(act)
            episode_reward += reward
            current_state = new_state
            
#         if ep>=1000:
#             print('over limit')
        rewards.append(episode_reward)
        episode_counts.append(ep)
    
    # all done
    mean_reward = sum(rewards)/len(rewards)
    mean_eps = sum(episode_counts)/len(episode_counts)
    return mean_reward, mean_eps, rewards, episode_counts

# %%
def value_iteration(env, discount=0.9, epsilon=1e-12):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    policy = np.zeros((1, number_of_states))
    value_list = np.zeros((1, number_of_states))
    old_value_list = value_list.copy()
    episode = 0
    max_change = 1
    sigma = discount
    while max_change > epsilon:
        episode += 1
        for s in range(number_of_states):
            assigned_value = -np.inf
            for a in range(number_of_actions):
                # get new state and its reward        
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    # get new states value
                    value_new_state = old_value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward 
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += cand_value*prob 
                        
                if total_cand_value > assigned_value:
                    assigned_value = total_cand_value
                    policy[0][s] = a
                    value_list[0][s] = assigned_value
        changes = np.abs(value_list - old_value_list)
        max_change = np.max(changes)
        old_value_list = value_list.copy()
        
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def policy_iteration(env, discount=0.9, epsilon=1e-3):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    ## 1
    policy = np.random.randint(number_of_actions, size=(1,number_of_states))
#     policy = np.zeros((1,number_of_states))
    value_list = np.zeros((1, number_of_states))
    episode = 0
    sigma = discount
    
    ## 2
    policy_stable = False
    while not policy_stable:
        episode += 1
        eval_acc = True
        while eval_acc:
            eps = 0
            for s in range(number_of_states):
                # first row
                v = value_list[0][s]

                # get the new value 
                a = policy[0][s]
                total_val_new_state = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    # second row
                    cand_value = 0
                    if done:
                        cand_value = reward                     
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_val_new_state += cand_value*prob 
                value_list[0][s] = total_val_new_state
                    
                # third row
                eps = max(eps, np.abs(v-value_list[0][s]))
            if eps < epsilon:
                eval_acc = False


        ## 3
        policy_stable = True
        for s in range(number_of_states):

            # assign 
            old_action = policy[0][s]
            # get the argmax a here
            max_value = -np.inf
            for a in range(number_of_actions):
                # get the new value 
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += prob*cand_value
                if total_cand_value > max_value:
                    max_value = total_cand_value
                    policy[0][s] = a

            # if old-action != policy[s]
            if old_action != policy[0][s]:
                policy_stable = False
    
    
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def train_and_test_pi_vi(env, discount=[0.9], epsilon=[1e-9], mute=False):
    
    vi_dict = {}
    
    for dis in discount:
        vi_dict[dis] = {}
        for eps in epsilon:
            vi_dict[dis][eps] = {}
            
            # run value iteration
            vi_policy, vi_solve_iter, vi_solve_time = value_iteration(env, dis, eps)
            vi_mrews, vi_meps, _, __ = test_policy(env, vi_policy)    
            vi_dict[dis][eps]["mean_reward"] = vi_mrews
            vi_dict[dis][eps]["mean_eps"] = vi_meps
            vi_dict[dis][eps]["iteration"] = vi_solve_iter
            vi_dict[dis][eps]["time_spent"] = vi_solve_time
            vi_dict[dis][eps]["policy"] = vi_policy
            if not mute:
                print("Value iteration for {} discount and {} eps is done".format(dis, eps))
                print("Iteration: {} time: {}".format(vi_solve_iter, vi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(vi_mrews, vi_meps))
    # run policy iteration
    pi_dict = {}
    for dis in discount:
        pi_dict[dis] = {}
        for eps in epsilon:
            pi_dict[dis][eps] = {}

            pi_policy, pi_solve_iter, pi_solve_time = policy_iteration(env, dis, eps)
            pi_mrews, pi_meps, _, __ = test_policy(env, pi_policy)    
            pi_dict[dis][eps]["mean_reward"] = pi_mrews
            pi_dict[dis][eps]["mean_eps"] = pi_meps
            pi_dict[dis][eps]["iteration"] = pi_solve_iter
            pi_dict[dis][eps]["time_spent"] = pi_solve_time
            pi_dict[dis][eps]["policy"] = pi_policy
            if not mute:
                print("Policy iteration for {} discount is done".format(dis))
                print("Iteration: {} time: {}".format(pi_solve_iter, pi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(pi_mrews, pi_meps))

    
    return vi_dict, pi_dict

# %%
def map_discretize(the_map):
    size = len(the_map)
    dis_map = np.zeros((size,size))
    for i, row in enumerate(the_map):
        for j, loc in enumerate(row):
            if loc == "S":
                dis_map[i, j] = 0
            elif loc == "F":
                dis_map[i, j] = 0
            elif loc == "H":
                dis_map[i, j] = -1
            elif loc == "G":
                dis_map[i, j] = 1
    return dis_map


def policy_numpy(policy):
    size = int(np.sqrt(len(policy)))
    pol = np.asarray(policy)
    pol = pol.reshape((size, size))
    return pol


def see_policy(map_size, policy):
    map_name = str(map_size)+"x"+str(map_size)
    data = map_discretize(MAPS[map_name])
    np_pol = policy_numpy(policy)
    plt.imshow(data, interpolation="nearest")

    for i in range(np_pol[0].size):
        for j in range(np_pol[0].size):
            arrow = '\u2190'
            if np_pol[i, j] == 1:
                arrow = '\u2193'
            elif np_pol[i, j] == 2:
                arrow = '\u2192'
            elif np_pol[i, j] == 3:
                arrow = '\u2191'
            text = plt.text(j, i, arrow,
                           ha="center", va="center", color="w")
    plt.show()

# %%
def plot_the_dict(dictionary, value="Score", size=4, variable="Discount Rate", log=False):

    plt.figure(figsize=(6, 4))
    title = "Average and Max {} on {}x{} Frozen Lake".format(value, size, size)
    the_val = value
    value = "Average {}".format(the_val)
    val_type = "Type of {}".format(the_val)
    the_df = pd.DataFrame(columns=[variable, value, val_type])
    for k, v in dictionary.items():
        for val in v:
            if not log:
                dic = {variable: k, value: float(val), val_type: "Average with std"}
            else:
                dic = {variable: np.log10(k), value: float(val), val_type: "Average with std"}                
            the_df = the_df.append(dic, ignore_index=True)
        if not log:
            dic = {variable: k, value: float(max(v)), val_type: "Max"}
        else:
            dic = {variable: np.log10(k), value: float(max(v)), val_type: "Max"}
        the_df = the_df.append(dic, ignore_index=True)
    sns.lineplot(x=variable, y=value, hue=val_type, style=val_type, markers=True, data=the_df).set(title=title)

# %%
def convert_dict_to_dict(the_dict):
    
    # return for discount
    discount_rewards = {}
    discount_iterations = {}
    discount_times = {}


    for disc in the_dict:
        discount_rewards[disc] = []    
        discount_iterations[disc] = []    
        discount_times[disc] = []

        for eps in the_dict[disc]:
            discount_rewards[disc].append(the_dict[disc][eps]['mean_reward'])
            discount_iterations[disc].append(the_dict[disc][eps]['iteration'])        
            discount_times[disc].append(the_dict[disc][eps]['time_spent'].total_seconds())  

            
    epsilon_rewards = {}
    epsilon_iterations = {}
    epsilon_times = {}
    for eps in the_dict[0.5]:
        epsilon_rewards[eps] = []    
        epsilon_iterations[eps] = []    
        epsilon_times[eps] = []
    
        for disc in vi_dict:
            epsilon_rewards[eps].append(the_dict[disc][eps]['mean_reward'])
            epsilon_iterations[eps].append(the_dict[disc][eps]['iteration'])        
            epsilon_times[eps].append(the_dict[disc][eps]['time_spent'].total_seconds()) 
            
    return discount_rewards, discount_iterations, discount_times, epsilon_rewards, epsilon_iterations, epsilon_times

# %% [markdown]
# ## 4x4

# %%
env = gym.make("FrozenLake-v0")
vi_dict, pi_dict = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                        epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
# Out:
# Solved in: 7 episodes and 0:00:00.001337 seconds
# Solved in: 16 episodes and 0:00:00.002986 seconds
# Solved in: 25 episodes and 0:00:00.004550 seconds
# Solved in: 34 episodes and 0:00:00.009388 seconds
# Solved in: 44 episodes and 0:00:00.008532 seconds
# Solved in: 12 episodes and 0:00:00.002301 seconds
# Solved in: 33 episodes and 0:00:00.006190 seconds
# Solved in: 53 episodes and 0:00:00.010590 seconds
# Solved in: 73 episodes and 0:00:00.014901 seconds
# Solved in: 94 episodes and 0:00:00.017829 seconds
# Solved in: 27 episodes and 0:00:00.005309 seconds
# Solved in: 78 episodes and 0:00:00.015250 seconds
# Solved in: 129 episodes and 0:00:00.025512 seconds
# Solved in: 179 episodes and 0:00:00.036581 seconds
# Solved in: 230 episodes and 0:00:00.044062 seconds
# Solved in: 44 episodes and 0:00:00.008146 seconds
# Solved in: 128 episodes and 0:00:00.024455 seconds
# Solved in: 213 episodes and 0:00:00.041617 seconds
# Solved in: 297 episodes and 0:00:00.054854 seconds
# Solved in: 381 episodes and 0:00:00.074585 seconds
# Solved in: 105 episodes and 0:00:00.020627 seconds
# Solved in: 305 episodes and 0:00:00.060151 seconds
# Solved in: 504 episodes and 0:00:00.097499 seconds
# Solved in: 704 episodes and 0:00:00.138381 seconds
# Solved in: 903 episodes and 0:00:00.178321 seconds
# Solved in: 149 episodes and 0:00:00.027510 seconds
# Solved in: 429 episodes and 0:00:00.081528 seconds
# Solved in: 709 episodes and 0:00:00.139070 seconds
# Solved in: 989 episodes and 0:00:00.189510 seconds
# Solved in: 1266 episodes and 0:00:00.249501 seconds
# Solved in: 4 episodes and 0:00:00.001760 seconds
# Solved in: 3 episodes and 0:00:00.002664 seconds
# Solved in: 4 episodes and 0:00:00.006446 seconds
# Solved in: 6 episodes and 0:00:00.008694 seconds
# Solved in: 4 episodes and 0:00:00.011133 seconds
# Solved in: 4 episodes and 0:00:00.002582 seconds
# Solved in: 6 episodes and 0:00:00.007832 seconds
# Solved in: 4 episodes and 0:00:00.010946 seconds
# Solved in: 8 episodes and 0:00:00.018801 seconds
# Solved in: 6 episodes and 0:00:00.024253 seconds
# Solved in: 4 episodes and 0:00:00.004140 seconds
# Solved in: 4 episodes and 0:00:00.012846 seconds
# Solved in: 4 episodes and 0:00:00.026616 seconds
# Solved in: 6 episodes and 0:00:00.037596 seconds
# Solved in: 4 episodes and 0:00:00.040806 seconds
# Solved in: 3 episodes and 0:00:00.005175 seconds
# Solved in: 3 episodes and 0:00:00.014271 seconds
# Solved in: 3 episodes and 0:00:00.022690 seconds
# Solved in: 4 episodes and 0:00:00.053605 seconds
# Solved in: 5 episodes and 0:00:00.078710 seconds
# Solved in: 6 episodes and 0:00:00.013290 seconds
# Solved in: 3 episodes and 0:00:00.035855 seconds
# Solved in: 3 episodes and 0:00:00.059629 seconds
# Solved in: 4 episodes and 0:00:00.094225 seconds
# Solved in: 7 episodes and 0:00:00.183379 seconds
# Solved in: 7 episodes and 0:00:00.019832 seconds
# Solved in: 3 episodes and 0:00:00.045126 seconds
# Solved in: 4 episodes and 0:00:00.103386 seconds
# Solved in: 4 episodes and 0:00:00.147718 seconds
# Solved in: 4 episodes and 0:00:00.154065 seconds

# %%
vi_dict[0.99]
# Out:
# {0.001: {'mean_reward': 0.751,
#   'mean_eps': 44.588,
#   'iteration': 105,
#   'time_spent': datetime.timedelta(microseconds=20627),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-06: {'mean_reward': 0.786,
#   'mean_eps': 43.621,
#   'iteration': 305,
#   'time_spent': datetime.timedelta(microseconds=60151),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-09: {'mean_reward': 0.723,
#   'mean_eps': 44.682,
#   'iteration': 504,
#   'time_spent': datetime.timedelta(microseconds=97499),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-12: {'mean_reward': 0.76,
#   'mean_eps': 43.714,
#   'iteration': 704,
#   'time_spent': datetime.timedelta(microseconds=138381),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-15: {'mean_reward': 0.739,
#   'mean_eps': 43.372,
#   'iteration': 903,
#   'time_spent': datetime.timedelta(microseconds=178321),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])}}

# %%
pi_dict[0.9999]
# Out:
# {0.001: {'mean_reward': 0.747,
#   'mean_eps': 43.454,
#   'iteration': 7,
#   'time_spent': datetime.timedelta(microseconds=19832),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-06: {'mean_reward': 0.739,
#   'mean_eps': 43.324,
#   'iteration': 3,
#   'time_spent': datetime.timedelta(microseconds=45126),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-09: {'mean_reward': 0.738,
#   'mean_eps': 45.033,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=103386),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-12: {'mean_reward': 0.724,
#   'mean_eps': 46.216,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=147718),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-15: {'mean_reward': 0.748,
#   'mean_eps': 44.362,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=154065),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])}}

# %%
pol = vi_dict[0.99][1e-12]['policy']
vi4 = convert_dict_to_dict(vi_dict)
see_policy(4, pol)

# %%
plot_the_dict(vi4[0], value="Score", size=4)

# %%
plot_the_dict(vi4[1], value="Iteration", size=4)

# %%
plot_the_dict(vi4[2], value="Time", size=4)

# %%
plot_the_dict(vi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %%
pol = pi_dict[0.99][1e-12]['policy']
pi4 = convert_dict_to_dict(pi_dict)
see_policy(4, pol)

# %%
plot_the_dict(pi4[0], value="Score", size=4)

# %%
plot_the_dict(pi4[1], value="Iteration", size=4)

# %%
plot_the_dict(pi4[2], value="Time", size=4)

# %%
plot_the_dict(pi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %% [markdown]
# ## 16 x 16

# %%
env = FrozenLakeEnv(desc=MAPS["16x16"])
vi_dict16, pi_dict16 = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                          epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
# Out:
# Solved in: 7 episodes and 0:00:00.016793 seconds
# Solved in: 15 episodes and 0:00:00.037330 seconds
# Solved in: 24 episodes and 0:00:00.059008 seconds
# Solved in: 34 episodes and 0:00:00.085809 seconds
# Solved in: 43 episodes and 0:00:00.103493 seconds
# Solved in: 12 episodes and 0:00:00.027512 seconds
# Solved in: 31 episodes and 0:00:00.075276 seconds
# Solved in: 54 episodes and 0:00:00.141722 seconds
# Solved in: 77 episodes and 0:00:00.194501 seconds
# Solved in: 100 episodes and 0:00:00.265692 seconds
# Solved in: 20 episodes and 0:00:00.053168 seconds
# Solved in: 77 episodes and 0:00:00.206467 seconds
# Solved in: 138 episodes and 0:00:00.364983 seconds
# Solved in: 199 episodes and 0:00:00.542906 seconds
# Solved in: 260 episodes and 0:00:00.703878 seconds
# Solved in: 31 episodes and 0:00:00.075465 seconds
# Solved in: 147 episodes and 0:00:00.383185 seconds
# Solved in: 268 episodes and 0:00:00.735462 seconds
# Solved in: 384 episodes and 0:00:01.098286 seconds
# Solved in: 499 episodes and 0:00:01.357488 seconds
# Solved in: 93 episodes and 0:00:00.247278 seconds
# Solved in: 518 episodes and 0:00:01.421487 seconds
# Solved in: 903 episodes and 0:00:02.596336 seconds
# Solved in: 1287 episodes and 0:00:03.590630 seconds
# Solved in: 1672 episodes and 0:00:04.749545 seconds
# Solved in: 302 episodes and 0:00:00.833142 seconds
# Solved in: 1449 episodes and 0:00:04.008977 seconds
# Solved in: 2587 episodes and 0:00:07.197847 seconds
# Solved in: 3723 episodes and 0:00:10.621438 seconds
# Solved in: 4854 episodes and 0:00:13.427737 seconds
# Solved in: 26 episodes and 0:00:00.105387 seconds
# Solved in: 14 episodes and 0:00:00.102740 seconds
# Solved in: 21 episodes and 0:00:00.163033 seconds
# Solved in: 18 episodes and 0:00:00.239646 seconds
# Solved in: 7 episodes and 0:00:00.146308 seconds
# Solved in: 26 episodes and 0:00:00.115270 seconds
# Solved in: 15 episodes and 0:00:00.118422 seconds
# Solved in: 7 episodes and 0:00:00.150529 seconds
# Solved in: 5 episodes and 0:00:00.235279 seconds
# Solved in: 16 episodes and 0:00:00.773086 seconds
# Solved in: 22 episodes and 0:00:00.119336 seconds
# Solved in: 18 episodes and 0:00:00.411098 seconds
# Solved in: 19 episodes and 0:00:01.021721 seconds
# Solved in: 19 episodes and 0:00:01.653931 seconds
# Solved in: 19 episodes and 0:00:02.263907 seconds
# Solved in: 15 episodes and 0:00:00.109766 seconds
# Solved in: 19 episodes and 0:00:00.829350 seconds
# Solved in: 8 episodes and 0:00:01.035395 seconds
# Solved in: 18 episodes and 0:00:03.027122 seconds
# Solved in: 19 episodes and 0:00:04.157242 seconds
# Solved in: 21 episodes and 0:00:00.372679 seconds
# Solved in: 19 episodes and 0:00:02.989774 seconds
# Solved in: 19 episodes and 0:00:07.498489 seconds
# Solved in: 8 episodes and 0:00:04.883468 seconds
# Solved in: 20 episodes and 0:00:14.969818 seconds
# Solved in: 18 episodes and 0:00:00.876003 seconds
# Solved in: 7 episodes and 0:00:03.451387 seconds
# Solved in: 8 episodes and 0:00:09.542533 seconds
# Solved in: 20 episodes and 0:00:43.216767 seconds
# Solved in: 20 episodes and 0:01:02.793445 seconds

# %%
pol = vi_dict16[0.9999][1e-15]['policy']
vi16 = convert_dict_to_dict(vi_dict16)
see_policy(16, pol)

# %%
plot_the_dict(vi16[0], value="Score", size=16)

# %%
plot_the_dict(vi16[1], value="Iteration", size=16)

# %%
plot_the_dict(vi16[2], value="Time", size=16)

# %%
#pi16 = convert_dict_to_dict(pi_dict16)

# %%
pol = pi_dict16[0.99][1e-12]['policy']
pi16 = convert_dict_to_dict(pi_dict16)
see_policy(16, pol)

# %%
plot_the_dict(pi16[0], value="Score", size=16)

# %%
plot_the_dict(pi16[1], value="Iteration", size=16)

# %%
plot_the_dict(pi16[2], value="Time", size=16)
